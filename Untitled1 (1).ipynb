# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

# %%
# 출력 옵션 설정
pd.set_option('display.max_columns', None)  # 모든 열 출력

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
# 	/Quezon City/Philippines -> Philippines 변경
df_train['customer_country'] = df_train['customer_country'].apply(lambda x: x.rsplit('/', 1)[-1].strip() if isinstance(x, str) else x)
df_train['customer_country'] = df_train['customer_country.1'].apply(lambda x: x.rsplit('/', 1)[-1].strip() if isinstance(x, str) else x)

# 	/Quezon City/Philippines -> Philippines 변경
df_test['customer_country'] = df_test['customer_country'].apply(lambda x: x.rsplit('/', 1)[-1].strip() if isinstance(x, str) else x)
df_test['customer_country'] = df_test['customer_country.1'].apply(lambda x: x.rsplit('/', 1)[-1].strip() if isinstance(x, str) else x)

# %%
df_all = pd.concat([df_train, df_test])
df_all.shape, df_train.shape, df_test.shape
# Out:
# C:\Users\hanji\AppData\Local\Temp\ipykernel_6828\2133486542.py:1: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   df_all = pd.concat([df_train, df_test])
# ((64570, 30), (59299, 29), (5271, 30))

# %%
# 열 삭제
drop_col = ['customer_country.1', 'id_strategic_ver', 'it_strategic_ver', 'idit_strategic_ver',
            'product_subcategory', 'product_modelname', 'business_area', 'business_subarea', 'ver_cus', 'ver_pro']

df_all.drop(columns = drop_col, inplace = True)
df_all.isnull().sum()
# Out:
# bant_submit                    0
# customer_country             982
# business_unit                  0
# com_reg_ver_win_rate       48214
# customer_idx                   0
# customer_type              45418
# enterprise                     0
# historical_existing_cnt    49539
# customer_job               20172
# lead_desc_length               0
# inquiry_type                2233
# product_category           21232
# customer_position              0
# response_corporate             0
# expected_timeline          33271
# ver_win_rate_x             43780
# ver_win_ratio_per_bu       47360
# lead_owner                     0
# is_converted                5271
# id                         59299
# dtype: int64

# %%
# 결측값 0으로 넣을 컬럼
fillna_col = ['com_reg_ver_win_rate', 'historical_existing_cnt',
             'ver_win_rate_x', 'ver_win_ratio_per_bu']

for col in fillna_col:
    df_all[col] = df_all[col].fillna(0)

df_all.isnull().sum()
# Out:
# bant_submit                    0
# customer_country             982
# business_unit                  0
# com_reg_ver_win_rate           0
# customer_idx                   0
# customer_type              45418
# enterprise                     0
# historical_existing_cnt        0
# customer_job               20172
# lead_desc_length               0
# inquiry_type                2233
# product_category           21232
# customer_position              0
# response_corporate             0
# expected_timeline          33271
# ver_win_rate_x                 0
# ver_win_ratio_per_bu           0
# lead_owner                     0
# is_converted                5271
# id                         59299
# dtype: int64

# %%
df_all['customer_type'] = df_all['customer_type'].str.lower()
df_all['customer_type'] = df_all['customer_type'].replace(['etc.', 'other', 'others'], 'etc')
df_all['customer_type'] = df_all['customer_type'].replace(['end-customer', 'end customer', 'end-user'], 'end_user')
df_all['customer_type'] = df_all['customer_type'].replace(['specifier/ influencer', 'specifier / influencer'], 'influencer')
df_all['customer_type'] = df_all['customer_type'].replace(['homeowner', 'home owner'], 'home_owner')
df_all['customer_type'] = df_all['customer_type'].replace(['software/solution provider', 'software / solution provider'], 'solution_provider')
df_all['customer_type'] = df_all['customer_type'].replace(['engineer', 'hvac engineer'], 'engineer')
df_all['customer_type'] = df_all['customer_type'].replace(['distributor', 'dealer/distributor'], 'distributor')
df_all['customer_type'].fillna('etc', inplace = True)

# %%
# value_counts 가 1개인 것들 etc로 분류
value_counts = df_all['customer_type'].value_counts()
values_to_replace = value_counts[value_counts == 1].index
df_all['customer_type'] = df_all['customer_type'].apply(lambda x: 'etc' if x in values_to_replace else x)

# %%
df_all['inquiry_type'] = df_all['inquiry_type'].str.lower()
df_all['inquiry_type'] = df_all['inquiry_type'].replace(['etc.', 'other', 'other_', 'others'], 'etc')
df_all['inquiry_type'] = df_all['inquiry_type'].replace(['sales inquiry', 'sales', 'probeam precio'], 'sales inquiry')
df_all['inquiry_type'] = df_all['inquiry_type'].replace(['quotation or purchase consultation', 'request for quotation or purchase', 'quotation_or_purchase_consultation', 'purchase or quotation', 'quotation_', 'purchase'], 'quotation_or_purchase_consultation')
df_all['inquiry_type'] = df_all['inquiry_type'].replace(['usage or technical consultation', 'technical consultation', 'request for technical consulting', 'usage_or_technical_consultation', 'technical_consultation', 'technical'], 'usage or technical consultation')
df_all['inquiry_type'] = df_all['inquiry_type'].replace(['vui lòng báo giá giúp mình sản phẩm đo thân nhiệt xin cảm ơn', 'tôi cần tham khảo giá và giải pháp từ lg'], 'quotation_or_purchase_consultation')
df_all['inquiry_type'] = df_all['inquiry_type'].replace(['toi muon tim hieu thong tin ky thuat, gia ca cua sp de su dung'], 'product information')

# %%
# value_counts 가 1개인 것들 etc로 분류
value_counts = df_all['inquiry_type'].value_counts()
values_to_replace = value_counts[value_counts == 1].index
df_all['inquiry_type'] = df_all['inquiry_type'].apply(lambda x: 'etc' if x in values_to_replace else x)

# %%
df_all['inquiry_type'].fillna('etc', inplace = True)

# %%
# 전처리 필요한 4개 컬럼 간단하게
value_counts = df_all['customer_job'].value_counts()
values_to_replace = value_counts[value_counts == 1].index
df_all['customer_job'] = df_all['customer_job'].apply(lambda x: 'other' if x in values_to_replace else x)
df_all['customer_job'].fillna('other', inplace = True)

value_counts = df_all['product_category'].value_counts()
values_to_replace = value_counts[value_counts == 1].index
df_all['product_category'] = df_all['product_category'].apply(lambda x: 'etc' if x in values_to_replace else x)
df_all['product_category'].fillna('etc', inplace = True)

value_counts = df_all['expected_timeline'].value_counts()
values_to_replace = value_counts[value_counts == 1].index
df_all['expected_timeline'] = df_all['expected_timeline'].apply(lambda x: 'etc' if x in values_to_replace else x)
df_all['expected_timeline'].fillna('etc', inplace = True)

value_counts = df_all['customer_country'].value_counts()
values_to_replace = value_counts[value_counts == 1].index
df_all['customer_country'] = df_all['customer_country'].apply(lambda x: 'etc' if x in values_to_replace else x)
df_all['customer_country'].fillna('etc', inplace = True)

# %%
def label_encoding(series: pd.Series) -> pd.Series:
    """범주형 데이터를 시리즈 형태로 받아 숫자형 데이터로 변환합니다."""

    my_dict = {}

    # 모든 요소를 문자열로 변환
    series = series.astype(str)

    for idx, value in enumerate(sorted(series.unique())):
        my_dict[value] = idx + 1
    series = series.map(my_dict)

    return series

# %%
# 레이블 인코딩할 칼럼들
label_columns = [
    "customer_country",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "customer_position",
    "response_corporate",
    "expected_timeline",
]

for col in label_columns:
    df_all[col] = label_encoding(df_all[col])

# %%
df_train = df_all.iloc[:len(df_train)]
df_test = df_all.iloc[len(df_train):]

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = pd.DataFrame(confusion_matrix(y_test, y_pred), index = ['T[0]', 'F[1]'], columns = ['pred_T[0]', 'pred_F[1]'])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
df_train.shape, df_test.shape
# Out:
# ((59299, 20), (5271, 20))

# %% [markdown]
# ### 언더샘플링

# %%
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from imblearn.under_sampling import RandomUnderSampler

X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_resample(df_train.drop(["is_converted", 'id'], axis=1), df_train["is_converted"].astype(int))

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_resampled,
    y_resampled,
    test_size=0.2,
    random_state=42,
)

# %% [markdown]
# ### Random Forest

# %%
rf_clf = RandomForestClassifier(random_state=42, oob_score = True)
param_grid = {'n_estimators' : np.arange(20, 101, 10),  'max_samples' : [0.8], 
              'max_features' : [0.8], 'criterion' : ["gini", "entropy", "log_loss"],
              'class_weight' : [{0:1, 1:1}]}

grid_rf_clf = GridSearchCV(rf_clf, param_grid, verbose = True, scoring='f1')
grid_rf_clf.fit(x_train, y_train)

print('최적의 파라미터 :', grid_rf_clf.best_params_)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# 최적의 파라미터 : {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 90}

# %%
rf_clf = RandomForestClassifier(random_state=42, n_estimators=80, criterion = 'entropy', 
                                max_features = 0.8, max_samples = 0.8, class_weight = {0: 1, 1:1}, oob_score = True)
rf_clf.fit(x_train, y_train)

y_pred = rf_clf.predict(x_val)
get_clf_eval(y_val, y_pred)

x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pred = rf_clf.predict(x_test)
sum(test_pred), len(test_pred) # True로 예측된 개수
# Out:
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        892         81
# F[1]         74        893
#
# 정확도: 0.9201
# 정밀도: 0.9168
# 재현율: 0.9235
# F1: 0.9201
# (2089, 5271)

# %%
# 변수 중요도
importances = pd.DataFrame(np.mean([tree.feature_importances_ for tree in rf_clf.estimators_], axis = 0))
feature_importances = pd.concat([pd.DataFrame(x_train.columns),importances], axis = 1)
feature_importances.columns = ['col_name', 'feature_importances']
feature_importances = feature_importances.sort_values(by = 'feature_importances', ascending= False).reset_index(drop = True)

# 변수중요도 시각화
sns.barplot(data = feature_importances, y = 'col_name', x = 'feature_importances')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier, AdaBoostClassifier

# %% [markdown]
# ### XGB

# %%
xgb = XGBClassifier(random_state=42)
param_grid = {'n_estimators' : [400, 500, 600, 700], 'learning_rate' : np.arange(0.01, 0.11, 0.02),
             'subsample' : [0.8], 'colsample_bytree' : [0.8]}

grid_xgb = GridSearchCV(xgb, param_grid, verbose = True, scoring='f1')
grid_xgb.fit(x_train, y_train)

print('최적의 파라미터 :', grid_xgb.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 최적의 파라미터 : {'colsample_bytree': 0.8, 'learning_rate': 0.06999999999999999, 'n_estimators': 400, 'subsample': 0.8}

# %%
y_pred = grid_xgb.predict(x_val.fillna(0))
get_clf_eval(y_val, y_pred)

x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pred = grid_xgb.predict(x_test.fillna(0))
sum(test_pred), len(test_pred) # True로 예측된 개수
# Out:
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         53        914
#
# 정확도: 0.9387
# 정밀도: 0.9327
# 재현율: 0.9452
# F1: 0.9389
# (1911, 5271)

# %% [markdown]
# ### AdaBoost

# %%
# AdaBoost 분류기를 정의합니다.
adaboost = AdaBoostClassifier(random_state=42)

# AdaBoost를 위한 매개변수 그리드를 정의합니다.
param_grid = {'n_estimators': [400, 500, 600, 700],
              'learning_rate': np.arange(0.01, 0.11, 0.02)}

# AdaBoost용 GridSearchCV 객체를 생성합니다.
grid_adaboost = GridSearchCV(adaboost, param_grid, verbose=True, scoring='f1')
grid_adaboost.fit(x_train, y_train)

print('최적의 파라미터 :', grid_adaboost.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 최적의 파라미터 : {'learning_rate': 0.08999999999999998, 'n_estimators': 600}

# %%
y_pred = grid_adaboost.predict(x_val.fillna(0))
get_clf_eval(y_val, y_pred)

x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pred = grid_adaboost.predict(x_test.fillna(0))
sum(test_pred), len(test_pred) # True로 예측된 개수
# Out:
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        873        100
# F[1]        146        821
#
# 정확도: 0.8732
# 정밀도: 0.8914
# 재현율: 0.8490
# F1: 0.8697
# (1777, 5271)

# %% [markdown]
# ### CatBoost

# %%
cat = CatBoostClassifier(random_state=42, verbose = False)
param_grid = {'iterations' : [800, 900, 1000, 1100], 'learning_rate' : np.arange(0.05, 0.15, 0.02),
             'subsample' : [0.8], 'colsample_bylevel' : [0.8]}

grid_cat = GridSearchCV(cat, param_grid, verbose = True, scoring='f1')
grid_cat.fit(x_train.fillna(0), y_train.astype(int))

print('최적의 파라미터 :', grid_cat.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 최적의 파라미터 : {'colsample_bylevel': 0.8, 'iterations': 1100, 'learning_rate': 0.07, 'subsample': 0.8}

# %%
y_pred = grid_cat.predict(x_val.fillna(0))
get_clf_eval(y_val, y_pred)

x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pred = grid_cat.predict(x_test.fillna(0))
sum(test_pred), len(test_pred) # True로 예측된 개수
# Out:
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        910         63
# F[1]         48        919
#
# 정확도: 0.9428
# 정밀도: 0.9358
# 재현율: 0.9504
# F1: 0.9430
# (1854, 5271)

# %% [markdown]
# ### Decision Tree

# %%
# Decision Tree 분류기를 정의합니다.
decision_tree = DecisionTreeClassifier(random_state=42)

# Decision Tree를 위한 매개변수 그리드를 정의합니다.
param_grid = {'max_depth': [None, 10, 20, 30],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

# Decision Tree용 GridSearchCV 객체를 생성합니다.
grid_decision_tree = GridSearchCV(decision_tree, param_grid, verbose=True, scoring='f1')
grid_decision_tree.fit(x_train, y_train)

print('최적의 파라미터 :', grid_decision_tree.best_params_)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# 최적의 파라미터 : {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
y_pred = grid_decision_tree.predict(x_val.fillna(0))
get_clf_eval(y_val, y_pred)

x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pred = grid_decision_tree.predict(x_test.fillna(0))
sum(test_pred), len(test_pred) # True로 예측된 개수
# Out:
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        872        101
# F[1]        108        859
#
# 정확도: 0.8923
# 정밀도: 0.8948
# 재현율: 0.8883
# F1: 0.8915
# (2069, 5271)

# %% [markdown]
# ### GradientBoosting

# %%
# Gradient Boosting 분류기를 정의합니다.
gradientboost = GradientBoostingClassifier(random_state=42)

# Gradient Boosting을 위한 매개변수 그리드를 정의합니다.
param_grid = {'n_estimators': [400, 500, 600, 700],
              'learning_rate': np.arange(0.01, 0.11, 0.02),
              'subsample': [0.8],
              'max_features': [0.8]}  # GradientBoosting에서는 max_features를 사용합니다.

# Gradient Boosting용 GridSearchCV 객체를 생성합니다.
grid_gradientboost = GridSearchCV(gradientboost, param_grid, verbose=True, scoring='f1')
grid_gradientboost.fit(x_train, y_train)

print('최적의 파라미터 :', grid_gradientboost.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 최적의 파라미터 : {'learning_rate': 0.08999999999999998, 'max_features': 0.8, 'n_estimators': 700, 'subsample': 0.8}

# %%
y_pred = grid_gradientboost.predict(x_val.fillna(0))
get_clf_eval(y_val, y_pred)

x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pred = grid_gradientboost.predict(x_test.fillna(0))
sum(test_pred), len(test_pred) # True로 예측된 개수
# Out:
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        902         71
# F[1]         57        910
#
# 정확도: 0.9340
# 정밀도: 0.9276
# 재현율: 0.9411
# F1: 0.9343
# (1961, 5271)

# %% [markdown]
# ### LGMB

# %%
lgbm = LGBMClassifier(random_state = 42, verbose = 0)
param_grid = {'learning_rate': np.arange(0.07, 0.14, 0.02), 'n_estimators': [100, 200, 300, 400, 500],
              'colsample_bytree': [0.8],'subsample': [0.8]}

grid_lgbm = GridSearchCV(lgbm, param_grid, verbose = True, scoring='f1')
grid_lgbm.fit(x_train, y_train)

print('최적의 파라미터 :', grid_lgbm.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 최적의 파라미터 : {'colsample_bytree': 0.8, 'learning_rate': 0.09000000000000001, 'n_estimators': 400, 'subsample': 0.8}

# %%
y_pred = grid_lgbm.predict(x_val.fillna(0))
get_clf_eval(y_val, y_pred)

x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pred = grid_lgbm.predict(x_test.fillna(0))
sum(test_pred), len(test_pred) # True로 예측된 개수
# Out:
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         51        916
#
# 정확도: 0.9418
# 정밀도: 0.9366
# 재현율: 0.9473
# F1: 0.9419
# (1978, 5271)

# %% [markdown]
# ### 앙상블

# %%
import itertools

# 모델 리스트
models = [
    ('xgb', grid_xgb.best_estimator_), 
    ('rf_clf', grid_rf_clf.best_estimator_), 
    ('adaboost', grid_adaboost.best_estimator_),
    ('catboost', grid_cat.best_estimator_),
    ('dt', grid_decision_tree.best_estimator_),
    ('gradient', grid_gradientboost.best_estimator_),
    ('lgbm', grid_lgbm.best_estimator_),    
]

# 모든 모델 조합 생성
model_combinations = []
for r in range(1, len(models) + 1):
    model_combinations.extend(list(itertools.combinations(models, r)))

# VotingClassifier를 위한 결과 딕셔너리
voting_results = {}

# VotingClassifier를 통한 앙상블 평가
for combination in model_combinations:
    model_names = [model[0] for model in combination]
    estimators = [(model[0], model[1]) for model in combination]
    
    voting_name = '_'.join(model_names) + '_voting'
    voting_classifier = VotingClassifier(estimators=estimators, voting='soft')
    voting_classifier.fit(x_train, y_train)
    
    y_pred_val = voting_classifier.predict(x_val)
    accuracy = accuracy_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    recall = recall_score(y_val, y_pred_val)
    f1 = f1_score(y_val, y_pred_val)
    confusion = pd.DataFrame(confusion_matrix(y_val, y_pred_val), index=['T[0]', 'F[1]'], columns=['pred_T[0]', 'pred_F[1]'])
    
    voting_results[voting_name] = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'confusion_matrix': confusion
    }

# F1 점수를 기준으로 정렬하여 출력
sorted_results = sorted(voting_results.items(), key=lambda x: x[1]['f1'], reverse=True)

for voting_name, result in sorted_results:
    print(f"모델 조합: {voting_name}")
    print(f"정확도: {result['accuracy']:.4f}")
    print(f"정밀도: {result['precision']:.4f}")
    print(f"재현율: {result['recall']:.4f}")
    print(f"F1 점수: {result['f1']:.4f}")
    print("오차행렬:\n", result['confusion_matrix'])
    print()
# Out:
# 모델 조합: xgb_rf_clf_gradient_lgbm_voting
# 정확도: 0.9443
# 정밀도: 0.9378
# 재현율: 0.9514
# F1 점수: 0.9446
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        912         61
# F[1]         47        920
#
# 모델 조합: xgb_rf_clf_adaboost_gradient_lgbm_voting
# 정확도: 0.9443
# 정밀도: 0.9378
# 재현율: 0.9514
# F1 점수: 0.9446
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        912         61
# F[1]         47        920
#
# 모델 조합: rf_clf_catboost_gradient_lgbm_voting
# 정확도: 0.9443
# 정밀도: 0.9387
# 재현율: 0.9504
# F1 점수: 0.9445
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        913         60
# F[1]         48        919
#
# 모델 조합: rf_clf_adaboost_catboost_gradient_lgbm_voting
# 정확도: 0.9443
# 정밀도: 0.9387
# 재현율: 0.9504
# F1 점수: 0.9445
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        913         60
# F[1]         48        919
#
# 모델 조합: adaboost_catboost_voting
# 정확도: 0.9433
# 정밀도: 0.9368
# 재현율: 0.9504
# F1 점수: 0.9435
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         48        919
#
# 모델 조합: catboost_gradient_lgbm_voting
# 정확도: 0.9433
# 정밀도: 0.9377
# 재현율: 0.9493
# F1 점수: 0.9435
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        912         61
# F[1]         49        918
#
# 모델 조합: xgb_catboost_gradient_lgbm_voting
# 정확도: 0.9433
# 정밀도: 0.9377
# 재현율: 0.9493
# F1 점수: 0.9435
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        912         61
# F[1]         49        918
#
# 모델 조합: adaboost_catboost_gradient_lgbm_voting
# 정확도: 0.9433
# 정밀도: 0.9377
# 재현율: 0.9493
# F1 점수: 0.9435
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        912         61
# F[1]         49        918
#
# 모델 조합: catboost_voting
# 정확도: 0.9428
# 정밀도: 0.9358
# 재현율: 0.9504
# F1 점수: 0.9430
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        910         63
# F[1]         48        919
#
# 모델 조합: catboost_lgbm_voting
# 정확도: 0.9428
# 정밀도: 0.9358
# 재현율: 0.9504
# F1 점수: 0.9430
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        910         63
# F[1]         48        919
#
# 모델 조합: adaboost_catboost_lgbm_voting
# 정확도: 0.9428
# 정밀도: 0.9358
# 재현율: 0.9504
# F1 점수: 0.9430
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        910         63
# F[1]         48        919
#
# 모델 조합: xgb_adaboost_catboost_gradient_lgbm_voting
# 정확도: 0.9428
# 정밀도: 0.9376
# 재현율: 0.9483
# F1 점수: 0.9429
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        912         61
# F[1]         50        917
#
# 모델 조합: xgb_catboost_voting
# 정확도: 0.9423
# 정밀도: 0.9331
# 재현율: 0.9524
# F1 점수: 0.9427
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         46        921
#
# 모델 조합: xgb_catboost_lgbm_voting
# 정확도: 0.9423
# 정밀도: 0.9340
# 재현율: 0.9514
# F1 점수: 0.9426
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         47        920
#
# 모델 조합: rf_clf_catboost_lgbm_voting
# 정확도: 0.9423
# 정밀도: 0.9340
# 재현율: 0.9514
# F1 점수: 0.9426
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         47        920
#
# 모델 조합: rf_clf_adaboost_catboost_lgbm_voting
# 정확도: 0.9423
# 정밀도: 0.9340
# 재현율: 0.9514
# F1 점수: 0.9426
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         47        920
#
# 모델 조합: rf_clf_gradient_lgbm_voting
# 정확도: 0.9423
# 정밀도: 0.9358
# 재현율: 0.9493
# F1 점수: 0.9425
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        910         63
# F[1]         49        918
#
# 모델 조합: rf_clf_adaboost_gradient_lgbm_voting
# 정확도: 0.9423
# 정밀도: 0.9358
# 재현율: 0.9493
# F1 점수: 0.9425
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        910         63
# F[1]         49        918
#
# 모델 조합: rf_clf_catboost_gradient_voting
# 정확도: 0.9423
# 정밀도: 0.9367
# 재현율: 0.9483
# F1 점수: 0.9424
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         50        917
#
# 모델 조합: rf_clf_adaboost_catboost_gradient_voting
# 정확도: 0.9423
# 정밀도: 0.9367
# 재현율: 0.9483
# F1 점수: 0.9424
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         50        917
#
# 모델 조합: xgb_adaboost_catboost_voting
# 정확도: 0.9418
# 정밀도: 0.9331
# 재현율: 0.9514
# F1 점수: 0.9421
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         47        920
#
# 모델 조합: xgb_rf_clf_catboost_gradient_lgbm_voting
# 정확도: 0.9418
# 정밀도: 0.9348
# 재현율: 0.9493
# F1 점수: 0.9420
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         49        918
#
# 모델 조합: xgb_rf_clf_adaboost_catboost_gradient_lgbm_voting
# 정확도: 0.9418
# 정밀도: 0.9348
# 재현율: 0.9493
# F1 점수: 0.9420
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         49        918
#
# 모델 조합: lgbm_voting
# 정확도: 0.9418
# 정밀도: 0.9366
# 재현율: 0.9473
# F1 점수: 0.9419
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         51        916
#
# 모델 조합: adaboost_lgbm_voting
# 정확도: 0.9418
# 정밀도: 0.9366
# 재현율: 0.9473
# F1 점수: 0.9419
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         51        916
#
# 모델 조합: xgb_gradient_lgbm_voting
# 정확도: 0.9418
# 정밀도: 0.9384
# 재현율: 0.9452
# F1 점수: 0.9418
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        913         60
# F[1]         53        914
#
# 모델 조합: xgb_rf_clf_lgbm_voting
# 정확도: 0.9412
# 정밀도: 0.9321
# 재현율: 0.9514
# F1 점수: 0.9417
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         47        920
#
# 모델 조합: xgb_rf_clf_adaboost_lgbm_voting
# 정확도: 0.9412
# 정밀도: 0.9321
# 재현율: 0.9514
# F1 점수: 0.9417
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         47        920
#
# 모델 조합: xgb_adaboost_catboost_lgbm_voting
# 정확도: 0.9412
# 정밀도: 0.9339
# 재현율: 0.9493
# F1 점수: 0.9415
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         49        918
#
# 모델 조합: gradient_lgbm_voting
# 정확도: 0.9412
# 정밀도: 0.9348
# 재현율: 0.9483
# F1 점수: 0.9415
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         50        917
#
# 모델 조합: xgb_rf_clf_adaboost_gradient_voting
# 정확도: 0.9412
# 정밀도: 0.9365
# 재현율: 0.9462
# F1 점수: 0.9414
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         52        915
#
# 모델 조합: xgb_adaboost_gradient_lgbm_voting
# 정확도: 0.9412
# 정밀도: 0.9374
# 재현율: 0.9452
# F1 점수: 0.9413
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        912         61
# F[1]         53        914
#
# 모델 조합: rf_clf_catboost_dt_gradient_lgbm_voting
# 정확도: 0.9412
# 정밀도: 0.9374
# 재현율: 0.9452
# F1 점수: 0.9413
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        912         61
# F[1]         53        914
#
# 모델 조합: xgb_rf_clf_catboost_lgbm_voting
# 정확도: 0.9407
# 정밀도: 0.9320
# 재현율: 0.9504
# F1 점수: 0.9411
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         48        919
#
# 모델 조합: xgb_rf_clf_adaboost_catboost_lgbm_voting
# 정확도: 0.9407
# 정밀도: 0.9320
# 재현율: 0.9504
# F1 점수: 0.9411
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         48        919
#
# 모델 조합: xgb_rf_clf_catboost_voting
# 정확도: 0.9407
# 정밀도: 0.9329
# 재현율: 0.9493
# F1 점수: 0.9411
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         49        918
#
# 모델 조합: adaboost_gradient_lgbm_voting
# 정확도: 0.9407
# 정밀도: 0.9338
# 재현율: 0.9483
# F1 점수: 0.9410
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         50        917
#
# 모델 조합: catboost_dt_gradient_lgbm_voting
# 정확도: 0.9407
# 정밀도: 0.9347
# 재현율: 0.9473
# F1 점수: 0.9409
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         51        916
#
# 모델 조합: adaboost_catboost_dt_gradient_lgbm_voting
# 정확도: 0.9407
# 정밀도: 0.9347
# 재현율: 0.9473
# F1 점수: 0.9409
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         51        916
#
# 모델 조합: xgb_rf_clf_gradient_voting
# 정확도: 0.9407
# 정밀도: 0.9365
# 재현율: 0.9452
# F1 점수: 0.9408
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         53        914
#
# 모델 조합: xgb_catboost_dt_gradient_lgbm_voting
# 정확도: 0.9407
# 정밀도: 0.9365
# 재현율: 0.9452
# F1 점수: 0.9408
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         53        914
#
# 모델 조합: xgb_adaboost_catboost_dt_gradient_lgbm_voting
# 정확도: 0.9407
# 정밀도: 0.9365
# 재현율: 0.9452
# F1 점수: 0.9408
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         53        914
#
# 모델 조합: rf_clf_adaboost_catboost_dt_gradient_lgbm_voting
# 정확도: 0.9407
# 정밀도: 0.9365
# 재현율: 0.9452
# F1 점수: 0.9408
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         53        914
#
# 모델 조합: xgb_catboost_gradient_voting
# 정확도: 0.9402
# 정밀도: 0.9320
# 재현율: 0.9493
# F1 점수: 0.9406
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         49        918
#
# 모델 조합: xgb_adaboost_catboost_gradient_voting
# 정확도: 0.9402
# 정밀도: 0.9320
# 재현율: 0.9493
# F1 점수: 0.9406
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         49        918
#
# 모델 조합: xgb_rf_clf_adaboost_catboost_voting
# 정확도: 0.9402
# 정밀도: 0.9329
# 재현율: 0.9483
# F1 점수: 0.9405
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         50        917
#
# 모델 조합: xgb_lgbm_voting
# 정확도: 0.9402
# 정밀도: 0.9346
# 재현율: 0.9462
# F1 점수: 0.9404
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         52        915
#
# 모델 조합: rf_clf_catboost_voting
# 정확도: 0.9397
# 정밀도: 0.9337
# 재현율: 0.9462
# F1 점수: 0.9399
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         52        915
#
# 모델 조합: rf_clf_lgbm_voting
# 정확도: 0.9397
# 정밀도: 0.9337
# 재현율: 0.9462
# F1 점수: 0.9399
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         52        915
#
# 모델 조합: xgb_adaboost_lgbm_voting
# 정확도: 0.9397
# 정밀도: 0.9337
# 재현율: 0.9462
# F1 점수: 0.9399
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         52        915
#
# 모델 조합: rf_clf_adaboost_catboost_voting
# 정확도: 0.9397
# 정밀도: 0.9337
# 재현율: 0.9462
# F1 점수: 0.9399
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         52        915
#
# 모델 조합: rf_clf_adaboost_lgbm_voting
# 정확도: 0.9397
# 정밀도: 0.9337
# 재현율: 0.9462
# F1 점수: 0.9399
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         52        915
#
# 모델 조합: xgb_rf_clf_catboost_gradient_voting
# 정확도: 0.9397
# 정밀도: 0.9337
# 재현율: 0.9462
# F1 점수: 0.9399
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         52        915
#
# 모델 조합: xgb_rf_clf_adaboost_catboost_gradient_voting
# 정확도: 0.9397
# 정밀도: 0.9337
# 재현율: 0.9462
# F1 점수: 0.9399
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         52        915
#
# 모델 조합: xgb_gradient_voting
# 정확도: 0.9397
# 정밀도: 0.9346
# 재현율: 0.9452
# F1 점수: 0.9398
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         53        914
#
# 모델 조합: xgb_adaboost_gradient_voting
# 정확도: 0.9397
# 정밀도: 0.9346
# 재현율: 0.9452
# F1 점수: 0.9398
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         53        914
#
# 모델 조합: xgb_rf_clf_catboost_dt_gradient_lgbm_voting
# 정확도: 0.9397
# 정밀도: 0.9346
# 재현율: 0.9452
# F1 점수: 0.9398
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         53        914
#
# 모델 조합: xgb_rf_clf_adaboost_catboost_dt_gradient_lgbm_voting
# 정확도: 0.9397
# 정밀도: 0.9346
# 재현율: 0.9452
# F1 점수: 0.9398
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         53        914
#
# 모델 조합: catboost_gradient_voting
# 정확도: 0.9392
# 정밀도: 0.9327
# 재현율: 0.9462
# F1 점수: 0.9394
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         52        915
#
# 모델 조합: xgb_dt_gradient_lgbm_voting
# 정확도: 0.9392
# 정밀도: 0.9336
# 재현율: 0.9452
# F1 점수: 0.9394
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         53        914
#
# 모델 조합: xgb_adaboost_dt_gradient_lgbm_voting
# 정확도: 0.9392
# 정밀도: 0.9336
# 재현율: 0.9452
# F1 점수: 0.9394
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         53        914
#
# 모델 조합: xgb_rf_clf_dt_gradient_lgbm_voting
# 정확도: 0.9392
# 정밀도: 0.9354
# 재현율: 0.9431
# F1 점수: 0.9392
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        910         63
# F[1]         55        912
#
# 모델 조합: xgb_rf_clf_adaboost_dt_gradient_lgbm_voting
# 정확도: 0.9392
# 정밀도: 0.9354
# 재현율: 0.9431
# F1 점수: 0.9392
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        910         63
# F[1]         55        912
#
# 모델 조합: adaboost_catboost_gradient_voting
# 정확도: 0.9387
# 정밀도: 0.9318
# 재현율: 0.9462
# F1 점수: 0.9389
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         52        915
#
# 모델 조합: xgb_voting
# 정확도: 0.9387
# 정밀도: 0.9327
# 재현율: 0.9452
# F1 점수: 0.9389
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         53        914
#
# 모델 조합: xgb_adaboost_voting
# 정확도: 0.9387
# 정밀도: 0.9327
# 재현율: 0.9452
# F1 점수: 0.9389
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         53        914
#
# 모델 조합: xgb_catboost_dt_lgbm_voting
# 정확도: 0.9387
# 정밀도: 0.9335
# 재현율: 0.9442
# F1 점수: 0.9388
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         54        913
#
# 모델 조합: xgb_rf_clf_catboost_dt_lgbm_voting
# 정확도: 0.9387
# 정밀도: 0.9335
# 재현율: 0.9442
# F1 점수: 0.9388
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         54        913
#
# 모델 조합: xgb_adaboost_catboost_dt_lgbm_voting
# 정확도: 0.9387
# 정밀도: 0.9335
# 재현율: 0.9442
# F1 점수: 0.9388
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         54        913
#
# 모델 조합: xgb_rf_clf_adaboost_catboost_dt_lgbm_voting
# 정확도: 0.9387
# 정밀도: 0.9335
# 재현율: 0.9442
# F1 점수: 0.9388
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         54        913
#
# 모델 조합: xgb_rf_clf_adaboost_catboost_dt_gradient_voting
# 정확도: 0.9387
# 정밀도: 0.9362
# 재현율: 0.9411
# F1 점수: 0.9386
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        911         62
# F[1]         57        910
#
# 모델 조합: xgb_rf_clf_catboost_dt_gradient_voting
# 정확도: 0.9381
# 정밀도: 0.9353
# 재현율: 0.9411
# F1 점수: 0.9381
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        910         63
# F[1]         57        910
#
# 모델 조합: rf_clf_catboost_dt_lgbm_voting
# 정확도: 0.9376
# 정밀도: 0.9334
# 재현율: 0.9421
# F1 점수: 0.9377
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         56        911
#
# 모델 조합: xgb_catboost_dt_gradient_voting
# 정확도: 0.9376
# 정밀도: 0.9343
# 재현율: 0.9411
# F1 점수: 0.9377
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         57        910
#
# 모델 조합: xgb_adaboost_catboost_dt_gradient_voting
# 정확도: 0.9376
# 정밀도: 0.9343
# 재현율: 0.9411
# F1 점수: 0.9377
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        909         64
# F[1]         57        910
#
# 모델 조합: rf_clf_gradient_voting
# 정확도: 0.9371
# 정밀도: 0.9307
# 재현율: 0.9442
# F1 점수: 0.9374
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         54        913
#
# 모델 조합: xgb_rf_clf_adaboost_voting
# 정확도: 0.9371
# 정밀도: 0.9307
# 재현율: 0.9442
# F1 점수: 0.9374
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         54        913
#
# 모델 조합: xgb_dt_lgbm_voting
# 정확도: 0.9371
# 정밀도: 0.9307
# 재현율: 0.9442
# F1 점수: 0.9374
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         54        913
#
# 모델 조합: rf_clf_adaboost_gradient_voting
# 정확도: 0.9371
# 정밀도: 0.9307
# 재현율: 0.9442
# F1 점수: 0.9374
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         54        913
#
# 모델 조합: xgb_adaboost_dt_lgbm_voting
# 정확도: 0.9371
# 정밀도: 0.9307
# 재현율: 0.9442
# F1 점수: 0.9374
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         54        913
#
# 모델 조합: rf_clf_adaboost_catboost_dt_lgbm_voting
# 정확도: 0.9371
# 정밀도: 0.9324
# 재현율: 0.9421
# F1 점수: 0.9372
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         56        911
#
# 모델 조합: xgb_rf_clf_voting
# 정확도: 0.9366
# 정밀도: 0.9297
# 재현율: 0.9442
# F1 점수: 0.9369
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        904         69
# F[1]         54        913
#
# 모델 조합: dt_gradient_lgbm_voting
# 정확도: 0.9366
# 정밀도: 0.9306
# 재현율: 0.9431
# F1 점수: 0.9368
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         55        912
#
# 모델 조합: catboost_dt_lgbm_voting
# 정확도: 0.9366
# 정밀도: 0.9315
# 재현율: 0.9421
# F1 점수: 0.9368
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         56        911
#
# 모델 조합: adaboost_catboost_dt_lgbm_voting
# 정확도: 0.9366
# 정밀도: 0.9315
# 재현율: 0.9421
# F1 점수: 0.9368
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         56        911
#
# 모델 조합: xgb_rf_clf_dt_lgbm_voting
# 정확도: 0.9361
# 정밀도: 0.9297
# 재현율: 0.9431
# F1 점수: 0.9363
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        904         69
# F[1]         55        912
#
# 모델 조합: xgb_rf_clf_adaboost_dt_lgbm_voting
# 정확도: 0.9361
# 정밀도: 0.9297
# 재현율: 0.9431
# F1 점수: 0.9363
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        904         69
# F[1]         55        912
#
# 모델 조합: adaboost_dt_gradient_lgbm_voting
# 정확도: 0.9361
# 정밀도: 0.9305
# 재현율: 0.9421
# F1 점수: 0.9363
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         56        911
#
# 모델 조합: xgb_adaboost_catboost_dt_voting
# 정확도: 0.9361
# 정밀도: 0.9332
# 재현율: 0.9390
# F1 점수: 0.9361
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        908         65
# F[1]         59        908
#
# 모델 조합: xgb_dt_gradient_voting
# 정확도: 0.9356
# 정밀도: 0.9305
# 재현율: 0.9411
# F1 점수: 0.9357
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         57        910
#
# 모델 조합: xgb_adaboost_dt_gradient_voting
# 정확도: 0.9356
# 정밀도: 0.9305
# 재현율: 0.9411
# F1 점수: 0.9357
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         57        910
#
# 모델 조합: rf_clf_catboost_dt_gradient_voting
# 정확도: 0.9356
# 정밀도: 0.9305
# 재현율: 0.9411
# F1 점수: 0.9357
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         57        910
#
# 모델 조합: rf_clf_adaboost_catboost_dt_gradient_voting
# 정확도: 0.9356
# 정밀도: 0.9305
# 재현율: 0.9411
# F1 점수: 0.9357
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         57        910
#
# 모델 조합: xgb_catboost_dt_voting
# 정확도: 0.9356
# 정밀도: 0.9322
# 재현율: 0.9390
# F1 점수: 0.9356
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        907         66
# F[1]         59        908
#
# 모델 조합: rf_clf_dt_gradient_lgbm_voting
# 정확도: 0.9351
# 정밀도: 0.9313
# 재현율: 0.9390
# F1 점수: 0.9351
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         59        908
#
# 모델 조합: rf_clf_adaboost_dt_gradient_lgbm_voting
# 정확도: 0.9351
# 정밀도: 0.9313
# 재현율: 0.9390
# F1 점수: 0.9351
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         59        908
#
# 모델 조합: xgb_rf_clf_dt_gradient_voting
# 정확도: 0.9345
# 정밀도: 0.9294
# 재현율: 0.9400
# F1 점수: 0.9347
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        904         69
# F[1]         58        909
#
# 모델 조합: xgb_rf_clf_adaboost_dt_gradient_voting
# 정확도: 0.9345
# 정밀도: 0.9294
# 재현율: 0.9400
# F1 점수: 0.9347
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        904         69
# F[1]         58        909
#
# 모델 조합: gradient_voting
# 정확도: 0.9340
# 정밀도: 0.9276
# 재현율: 0.9411
# F1 점수: 0.9343
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        902         71
# F[1]         57        910
#
# 모델 조합: xgb_rf_clf_adaboost_catboost_dt_voting
# 정확도: 0.9340
# 정밀도: 0.9311
# 재현율: 0.9369
# F1 점수: 0.9340
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         61        906
#
# 모델 조합: adaboost_gradient_voting
# 정확도: 0.9335
# 정밀도: 0.9276
# 재현율: 0.9400
# F1 점수: 0.9337
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        902         71
# F[1]         58        909
#
# 모델 조합: xgb_rf_clf_catboost_dt_voting
# 정확도: 0.9335
# 정밀도: 0.9302
# 재현율: 0.9369
# F1 점수: 0.9335
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        905         68
# F[1]         61        906
#
# 모델 조합: catboost_dt_gradient_voting
# 정확도: 0.9335
# 정밀도: 0.9311
# 재현율: 0.9359
# F1 점수: 0.9335
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         62        905
#
# 모델 조합: adaboost_catboost_dt_gradient_voting
# 정확도: 0.9335
# 정밀도: 0.9311
# 재현율: 0.9359
# F1 점수: 0.9335
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        906         67
# F[1]         62        905
#
# 모델 조합: rf_clf_dt_lgbm_voting
# 정확도: 0.9294
# 정밀도: 0.9243
# 재현율: 0.9349
# F1 점수: 0.9296
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        899         74
# F[1]         63        904
#
# 모델 조합: rf_clf_adaboost_dt_lgbm_voting
# 정확도: 0.9294
# 정밀도: 0.9243
# 재현율: 0.9349
# F1 점수: 0.9296
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        899         74
# F[1]         63        904
#
# 모델 조합: xgb_rf_clf_dt_voting
# 정확도: 0.9263
# 정밀도: 0.9221
# 재현율: 0.9307
# F1 점수: 0.9264
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        897         76
# F[1]         67        900
#
# 모델 조합: xgb_rf_clf_adaboost_dt_voting
# 정확도: 0.9263
# 정밀도: 0.9221
# 재현율: 0.9307
# F1 점수: 0.9264
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        897         76
# F[1]         67        900
#
# 모델 조합: rf_clf_catboost_dt_voting
# 정확도: 0.9263
# 정밀도: 0.9230
# 재현율: 0.9297
# F1 점수: 0.9263
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        898         75
# F[1]         68        899
#
# 모델 조합: rf_clf_adaboost_catboost_dt_voting
# 정확도: 0.9263
# 정밀도: 0.9230
# 재현율: 0.9297
# F1 점수: 0.9263
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        898         75
# F[1]         68        899
#
# 모델 조합: rf_clf_adaboost_voting
# 정확도: 0.9216
# 정밀도: 0.9162
# 재현율: 0.9276
# F1 점수: 0.9219
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        891         82
# F[1]         70        897
#
# 모델 조합: rf_clf_dt_gradient_voting
# 정확도: 0.9211
# 정밀도: 0.9162
# 재현율: 0.9266
# F1 점수: 0.9213
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        891         82
# F[1]         71        896
#
# 모델 조합: rf_clf_adaboost_dt_gradient_voting
# 정확도: 0.9211
# 정밀도: 0.9162
# 재현율: 0.9266
# F1 점수: 0.9213
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        891         82
# F[1]         71        896
#
# 모델 조합: rf_clf_voting
# 정확도: 0.9211
# 정밀도: 0.9170
# 재현율: 0.9255
# F1 점수: 0.9213
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        892         81
# F[1]         72        895
#
# 모델 조합: adaboost_dt_lgbm_voting
# 정확도: 0.9165
# 정밀도: 0.9128
# 재현율: 0.9204
# F1 점수: 0.9166
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        888         85
# F[1]         77        890
#
# 모델 조합: dt_lgbm_voting
# 정확도: 0.9139
# 정밀도: 0.9090
# 재현율: 0.9193
# F1 점수: 0.9141
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        884         89
# F[1]         78        889
#
# 모델 조합: adaboost_catboost_dt_voting
# 정확도: 0.9129
# 정밀도: 0.9105
# 재현율: 0.9152
# F1 점수: 0.9128
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        886         87
# F[1]         82        885
#
# 모델 조합: catboost_dt_voting
# 정확도: 0.9113
# 정밀도: 0.9085
# 재현율: 0.9142
# F1 점수: 0.9113
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        884         89
# F[1]         83        884
#
# 모델 조합: xgb_adaboost_dt_voting
# 정확도: 0.9098
# 정밀도: 0.9082
# 재현율: 0.9111
# F1 점수: 0.9097
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        884         89
# F[1]         86        881
#
# 모델 조합: xgb_dt_voting
# 정확도: 0.9088
# 정밀도: 0.9064
# 재현율: 0.9111
# F1 점수: 0.9087
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        882         91
# F[1]         86        881
#
# 모델 조합: adaboost_dt_gradient_voting
# 정확도: 0.9046
# 정밀도: 0.9023
# 재현율: 0.9069
# F1 점수: 0.9046
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        878         95
# F[1]         90        877
#
# 모델 조합: dt_gradient_voting
# 정확도: 0.9041
# 정밀도: 0.9022
# 재현율: 0.9059
# F1 점수: 0.9040
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        878         95
# F[1]         91        876
#
# 모델 조합: rf_clf_dt_voting
# 정확도: 0.8990
# 정밀도: 0.8954
# 재현율: 0.9028
# F1 점수: 0.8991
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        871        102
# F[1]         94        873
#
# 모델 조합: rf_clf_adaboost_dt_voting
# 정확도: 0.8990
# 정밀도: 0.8954
# 재현율: 0.9028
# F1 점수: 0.8991
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        871        102
# F[1]         94        873
#
# 모델 조합: adaboost_dt_voting
# 정확도: 0.8943
# 정밀도: 0.8912
# 재현율: 0.8976
# F1 점수: 0.8944
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        867        106
# F[1]         99        868
#
# 모델 조합: dt_voting
# 정확도: 0.8923
# 정밀도: 0.8948
# 재현율: 0.8883
# F1 점수: 0.8915
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        872        101
# F[1]        108        859
#
# 모델 조합: adaboost_voting
# 정확도: 0.8732
# 정밀도: 0.8914
# 재현율: 0.8490
# F1 점수: 0.8697
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        873        100
# F[1]        146        821

# %%
# 보팅에 사용할 모델들 선택
selected_models = [
    ('xgb', grid_xgb.best_estimator_), 
    ('rf_clf', grid_rf_clf.best_estimator_), 
    ('gradient', grid_gradientboost.best_estimator_),
    ('lgbm', grid_lgbm.best_estimator_),
    ('adaboost', grid_adaboost.best_estimator_)
]

# VotingClassifier 정의
vote = VotingClassifier(estimators=selected_models, voting='soft')

# 모델 학습
vote.fit(x_train, y_train)

# 검증 데이터에 대한 예측
y_pred = vote.predict(x_val)

# 결과 출력
get_clf_eval(y_val, y_pred)

x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pred = vote.predict(x_test)
sum(test_pred), len(test_pred)
# Out:
# 오차행렬:
#        pred_T[0]  pred_F[1]
# T[0]        912         61
# F[1]         47        920
#
# 정확도: 0.9443
# 정밀도: 0.9378
# 재현율: 0.9514
# F1: 0.9446
# (1967, 5271)

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["is_converted"] = test_pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)
